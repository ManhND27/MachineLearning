# %%
using DelimitedFiles

# %%
A = readdlm("data/forbes.txt",' ',Float64,'\n')
# Out:
# 17×2 Array{Float64,2}:
#  194.5  20.79
#  194.3  20.79
#  197.9  22.4
#  198.4  22.67
#  199.4  23.15
#  199.9  23.35
#  200.9  23.89
#  201.1  23.99
#  201.4  24.02
#  201.3  24.01
#  203.6  25.14
#  204.6  26.57
#  209.5  28.49
#  208.6  27.76
#  210.7  29.04
#  211.9  29.88
#  212.2  30.06

# %%
temp = A[:,1]
# Out:
# 17-element Array{Float64,1}:
#  194.5
#  194.3
#  197.9
#  198.4
#  199.4
#  199.9
#  200.9
#  201.1
#  201.4
#  201.3
#  203.6
#  204.6
#  209.5
#  208.6
#  210.7
#  211.9
#  212.2

# %%
pressure = A[:,2]
# Out:
# 17-element Array{Float64,1}:
#  20.79
#  20.79
#  22.4
#  22.67
#  23.15
#  23.35
#  23.89
#  23.99
#  24.02
#  24.01
#  25.14
#  26.57
#  28.49
#  27.76
#  29.04
#  29.88
#  30.06

# %%
using Plots

# %%
plot(temp, pressure, seriestype = :scatter)
