# %%
using Plots

# %%
A = [3 4 5;5 6 7;5 7 8]
# Out:
# 3×3 Array{Int64,2}:
#  3  4  5
#  5  6  7
#  5  7  8

# %%
sum(Int.(A[:,:]).==5)
# Out:
# 3

# %%
B = [3 4 5 4 1;5 6 7 3 2;5 7 8 1 3; 1 2 4 5 6]
# Out:
# 4×5 Array{Int64,2}:
#  3  4  5  4  1
#  5  6  7  3  2
#  5  7  8  1  3
#  1  2  4  5  6

# %%
K ,D = size(B)
# Out:
# (4, 5)

# %%
sum(B[:,1:2:D])
# Out:
# 50

# %%
plot([1, 2],[3, 4])

# %%
I = eye(2);
# Out:
# UndefVarError: eye not defined
#
# Stacktrace:
#  [1] top-level scope at In[10]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\ThinkPro\.julia\packages\IJulia\a1SNk\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\ThinkPro\.julia\packages\IJulia\a1SNk\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\ThinkPro\.julia\packages\IJulia\a1SNk\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
import cv2
# Out:
# ArgumentError: Package cv2 not found in current path:
# - Run `import Pkg; Pkg.add("cv2")` to install the cv2 package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at .\loading.jl:893
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\ThinkPro\.julia\packages\IJulia\a1SNk\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\ThinkPro\.julia\packages\IJulia\a1SNk\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\ThinkPro\.julia\packages\IJulia\a1SNk\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356
